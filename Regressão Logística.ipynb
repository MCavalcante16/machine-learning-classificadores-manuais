# %%
import maurikit_learn as ml
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dados

# %%
#Embaralha dados
dados = np.loadtxt("ex2data1.txt", delimiter=",")

#Embaralhando as amostras
np.random.shuffle(dados)

#Separa dados
X = dados[:,0:2]
y = dados[:,2]

#Normalização
X = (X - X.min()) / (X.max() - X.min())

#Separação de conjunto de treino e conjunto de teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Usando Gradiente Descendente

# %%
LRG = ml.LogisticRegression_GRAD()

# %%
LRG.fit(X_train, y_train, learning_rate=0.2, epochs=500)
# Out:
# [1. 1. 1.]
# Coeficientes: [-2.65440566  3.44205342  2.9273423 ]

# %%
y_pred = LRG.predict(X_test)

# %% [markdown]
# ### Acurácia

# %%
ml.acuracia(y_test, y_pred)
# Out:
# 0.9666666666666667

# %% [markdown]
# ### Matriz de Confusão

# %%
ml.plot_confusion_matrix(LRG, X_test, y_test)
# Out:
# Matriz de Confusão
# [[11  1]
#  [ 0 18]]

# %% [markdown]
# ### Gráfico de Dispersão

# %%
ml.plot_boundaries(LRG, X, y)

# %% [markdown]
# # Naive Bayes Gaussiano

# %%
NBG = ml.LogisticRegression_NBG()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-9780db6b8bb7> in <module>
# ----> 1 NBG = ml.LogisticRegression_NBG()
#
# AttributeError: module 'maurikit_learn' has no attribute 'LogisticRegression_NBG'
