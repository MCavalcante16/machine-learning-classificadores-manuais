# %%
import maurikit_learn as ml
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dados

# %%
#Embaralha dados
dados = np.loadtxt("ex2data1.txt", delimiter=",")

#Embaralhando as amostras
np.random.shuffle(dados)

#Separa dados
X = dados[:,0:2]
y = dados[:,2]

#Normalização
X = (X - X.min()) / (X.max() - X.min())

#Separação de conjunto de treino e conjunto de teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# # Usando Gradiente Descendente

# %%
LRG = ml.LogisticRegression_GRAD()

# %%
LRG.fit(X_train, y_train, learning_rate=0.2, epochs=500)
# Out:
# [1. 1. 1.]
# Coeficientes: [-2.71763722  3.69599383  2.79266911]

# %%
y_pred = LRG.predict(X_test)

# %% [markdown]
# ### Acurácia

# %%
ml.acuracia(y_test, y_pred)
# Out:
# 0.9333333333333333

# %% [markdown]
# ### Matriz de Confusão

# %%
ml.plot_confusion_matrix(LRG, X_test, y_test)
# Out:
# Matriz de Confusão
# [[ 8  2]
#  [ 0 20]]

# %% [markdown]
# ### Gráfico de Dispersão

# %%
ml.plot_boundaries(LRG, X, y)

# %% [markdown]
# # Naive Bayes Gaussiano

# %%
NBG = ml.Classification_NBG()

# %%
NBG.fit(X_train, y_train)

# %%
nbg_pred = NBG.predict(X_test)

# %% [markdown]
# ### Acurácia

# %%
ml.acuracia(y_test, nbg_pred)
# Out:
# 0.9333333333333333

# %% [markdown]
# ### Matriz de Confusão

# %%
ml.plot_confusion_matrix(NBG, X_test, y_test)
# Out:
# Matriz de Confusão
# [[ 8  2]
#  [ 0 20]]

# %% [markdown]
# ### Gráfico de Dispersão

# %%
ml.plot_boundaries(NBG, X, y)

# %% [markdown]
# # Discriminante Quadrático Gaussiano

# %%
DC = ml.Classification_QD()

# %%
DC.fit(X_train, y_train)

# %%
dc_pred = DC.predict(X_test)

# %% [markdown]
# ### Acurácia

# %%
ml.acuracia(y_test, dc_pred)
# Out:
# 0.9

# %% [markdown]
# ### Matriz de Confusão

# %%
ml.plot_confusion_matrix(DC, X_test, y_test)
# Out:
# Matriz de Confusão
# [[ 8  2]
#  [ 1 19]]

# %%
ml.plot_boundaries(DC, X, y)

# %% [markdown]
# # Conclusões

# %% [markdown]
# * Todos os dados parecem ser linearmente separáveis
# * Os métodos de Gradiente Descendente e Naive Bayes Gaussiano apresentaram fronteiras lineares, enquanto o Discriminante Quadrático Gaussiano apresentou fronteira não linear
# * Os métodos de Gradiente Descendente e Naive Bayes Gaussiano apresentaram a melhor acurácia
